# %%
import pandas as pd 

df=pd.read_csv('pokemon_data.csv')
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df_xlsx=pd.read_excel('pokemon_data.xlsx')
df_xlsx
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_csv=pd.read_csv('pokemon_data.csv')
df_csv
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#SHOWING COLUMN NAMES

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#FILTERING BY COLUMN NAMES

# %%
df[['Name', 'Type 1', 'Type 2', 'HP']]
# Out:
#                       Name   Type 1  Type 2  HP
# 0                Bulbasaur    Grass  Poison  45
# 1                  Ivysaur    Grass  Poison  60
# 2                 Venusaur    Grass  Poison  80
# 3    VenusaurMega Venusaur    Grass  Poison  80
# 4               Charmander     Fire     NaN  39
# ..                     ...      ...     ...  ..
# 795                Diancie     Rock   Fairy  50
# 796    DiancieMega Diancie     Rock   Fairy  50
# 797    HoopaHoopa Confined  Psychic   Ghost  80
# 798     HoopaHoopa Unbound  Psychic    Dark  80
# 799              Volcanion     Fire   Water  80
#
# [800 rows x 4 columns]

# %%
#ACSESSING BY COORDS

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
for index, row in df.iterrows():
    print(index,row, '\n')
# Out:
#          62
# Sp. Def           57
# Speed             52
# Generation         6
# Legendary      False
# Name: 740, dtype: object
#
# 741 #                673
# Name          Gogoat
# Type 1         Grass
# Type 2           NaN
# HP               123
# Attack           100
# Defense           62
# Sp. Atk           97
# Sp. Def           81
# Speed             68
# Generation         6
# Legendary      False
# Name: 741, dtype: object
#
# 742 #                  674
# Name           Pancham
# Type 1        Fighting
# Type 2             NaN
# HP                  67
# Attack              82
# Defense             62
# Sp. Atk             46
# Sp. Def             48
# Speed               43
# Generation           6
# Legendary        False
# Name: 742, dtype: object
#
# 743 #                  675
# Name           Pangoro
# Type 1        Fighting
# Type 2            Dark
# HP                  95
# Attack             124
# Defense             78
# Sp. Atk             69
# ...

# %%
#FILTERING BY COLUMNS VALUES

# %%
df.loc[df['Type 1']=='Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 0      1              Bulbasaur  Grass  Poison     45           1      False
# 1      2                Ivysaur  Grass  Poison     60           1      False
# 2      3               Venusaur  Grass  Poison     80           1      False
# 3      3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 4      4             Charmander   Fire     NaN     65           1      False
# ..   ...                    ...    ...     ...    ...         ...        ...
# 735  667                 Litleo   Fire  Normal     72           6      False
# 736  668                 Pyroar   Fire  Normal    106           6      False
# 740  672                 Skiddo  Grass     NaN     52           6      False
# 741  673                 Gogoat  Grass     NaN     68           6      False
# 799  721              Volcanion   Fire   Water     70           6       True
#
# ...

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]
# Out:
#        #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 0      1              Bulbasaur  Grass  Poison     45           1      False
# 1      2                Ivysaur  Grass  Poison     60           1      False
# 2      3               Venusaur  Grass  Poison     80           1      False
# 3      3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 48    43                 Oddish  Grass  Poison     30           1      False
# 49    44                  Gloom  Grass  Poison     40           1      False
# 50    45              Vileplume  Grass  Poison     50           1      False
# 75    69             Bellsprout  Grass  Poison     40           1      False
# 76    70             Weepinbell  Grass  Poison     55           1      False
# 77    71             Victreebel  Grass  Poison     70           1      False
# 344  315                Roselia  Grass  Poison     65           3      False
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.loc[df['Name'].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2  Speed  Generation  \
# 3      3      VenusaurMega Venusaur     Grass    Poison     80           1
# 7      6  CharizardMega Charizard X      Fire    Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire    Flying    100           1
# 12     9    BlastoiseMega Blastoise     Water       NaN     78           1
# 19    15      BeedrillMega Beedrill       Bug    Poison    145           1
# 23    18        PidgeotMega Pidgeot    Normal    Flying    121           1
# 71    65      AlakazamMega Alakazam   Psychic       NaN    150           1
# 87    80        SlowbroMega Slowbro     Water   Psychic     30           1
# 102   94          GengarMega Gengar     Ghost    Poison    130           1
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    100           1
# 137  127          PinsirMega Pinsir       Bug    Flying    105           1
# ...

# %%
#SORTING BY VALUES

# %%
df.sort_values(['Name'], ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name','HP'], ascending=[0,1])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#ADDING NEW COLUMNS

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#DELETING COLUMNS

# %%
df=df.drop(columns=['Total'])
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#REARRANGING COLUMNS

# %%
df['Total']=df.iloc[:,4:10].sum(axis=1)

cols = list(df.columns)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]

df.head()
# Out:
#    #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 0  1              Bulbasaur  Grass  Poison     45           1      False
# 1  2                Ivysaur  Grass  Poison     60           1      False
# 2  3               Venusaur  Grass  Poison     80           1      False
# 3  3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 4  4             Charmander   Fire     NaN     65           1      False
#
#     Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0   943.0  45      49       49       65       65
# 1  1201.0  60      62       63       80       80
# 2  1561.0  80      82       83      100      100
# 3  1899.0  80     100      123      122      120
# 4   882.0  39      52       43       60       50

# %%
#MODIFYING BY VALUES

# %%
new_df=df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') &(df['HP'] > 70)]
new_df
# Out:
#        #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 2      3               Venusaur  Grass  Poison     80           1      False
# 3      3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 50    45              Vileplume  Grass  Poison     50           1      False
# 77    71             Victreebel  Grass  Poison     70           1      False
# 652  591              Amoonguss  Grass  Poison     30           5      False
#
#       Total   HP  Attack  Defense  Sp. Atk  Sp. Def
# 2    1561.0   80      82       83      100      100
# 3    1899.0   80     100      123      122      120
# 50   1521.0   75      80       85      110       90
# 77   1511.0   80     105       65      100       70
# 652  1526.0  114      85       70       85       80

# %%
df.loc[df['Total']>500, ['Generation', 'Legendary']]=['Test 1', 'Test 2']
df
# Out:
#        #                   Name   Type 1  Type 2  Speed Generation Legendary  \
# 0      1              Bulbasaur    Grass  Poison     45     Test 1    Test 2
# 1      2                Ivysaur    Grass  Poison     60     Test 1    Test 2
# 2      3               Venusaur    Grass  Poison     80     Test 1    Test 2
# 3      3  VenusaurMega Venusaur    Grass  Poison     80     Test 1    Test 2
# 4      4             Charmander     Fire     NaN     65     Test 1    Test 2
# ..   ...                    ...      ...     ...    ...        ...       ...
# 795  719                Diancie     Rock   Fairy     50     Test 1    Test 2
# 796  719    DiancieMega Diancie     Rock   Fairy    110     Test 1    Test 2
# 797  720    HoopaHoopa Confined  Psychic   Ghost     70     Test 1    Test 2
# 798  720     HoopaHoopa Unbound  Psychic    Dark     80     Test 1    Test 2
# 799  721              Volcanion     Fire   Water     70     Test 1    Test 2
#
# ...

# %%
df=pd.read_csv('pokemon_data.csv')
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
#WRITING TO CSV

# %%
df.to_csv('mod_pockemon_data.csv')

df.to_csv('mod_pockemon_data.csv', index=False, sep=',')

# %%
#WRITING TO EXCEL

# %%
df.to_excel('mod_pockemon_data.xlsx', index=False)

# %%
#GROUPBY

# %%
df.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df['Count']=1
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Count
# 0         65       65     45           1      False      1
# ...

# %%
df.groupby(['Type 1']).count()['Count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %%
#LARGE AMOUNT OF DATA

# %%
new_df=pd.DataFrame(columns=df.columns)

for df in pd.read_csv('mod_pockemon_data.csv', chunksize=5):
    results=df.groupby(['Type 1']).count()

    new_df=pd.concat([new_df, results])

new_df
# Out:
#         Unnamed: 0  # Name Type 1 Type 2 Speed Generation Legendary Total HP  \
# Fire             1  1    1    NaN      0     1          1         1     1  1
# Grass            4  4    4    NaN      4     4          4         4     4  4
# Fire             4  4    4    NaN      3     4          4         4     4  4
# Water            1  1    1    NaN      0     1          1         1     1  1
# Bug              2  2    2    NaN      0     2          2         2     2  2
# ...            ... ..  ...    ...    ...   ...        ...       ...   ... ..
# Fairy            1  1    1    NaN      0     1          1         1     1  1
# Flying           2  2    2    NaN      2     2          2         2     2  2
# Fire             1  1    1    NaN      1     1          1         1     1  1
# Psychic          2  2    2    NaN      2     2          2         2     2  2
# Rock             2  2    2    NaN      2     2          2         2     2  2
#
#         Attack Defense Sp. Atk Sp. Def
# ...
